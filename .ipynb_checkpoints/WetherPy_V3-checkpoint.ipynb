# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
# import pprint as pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output/cities.csv"
print(output_data_file)


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
cityNumLimit = 2  # limit how many API calls we do while dev/testing
DEBUG = False
USEAPI = True
# Out:
# output/cities.csv

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    ############## an improvement may be to get the country code also
# >>> from citipy import citipy
# >>> city = citipy.nearest_city(22.99, 120.21)
# >>> city
# <citipy.City instance at 0x1069b6518>
# >>>
# >>> city.city_name     # Tainan, my home town
# 'tainan'
# >>>
# >>> city.country_code
# 'tw'                  # And the country is surely Taiwan


    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# api.openweathermap.org/data/2.5/weather?q={city name}
# api.openweathermap.org/data/2.5/weather?unitsImperial&APPID={api_key}q={city name}

if USEAPI:
    
    cityWeather = []
    cnt = 0
    for city in cities:
        cnt +=1
        print(f'Count is {cnt} city is {city}')
        url = f'http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID={api_key}&q={city}'
        print(f'{url}')
        response = requests.get(url).json()
        if DEBUG:
            print(response)

        # Check for city not found error
        if int(response['cod']) == 404:
            print(f'Skipping city {city}, city not found')

        else:
            # city
            cloudiness = response['clouds']['all']
            country = response['sys']['country']
            humidity = response['main']['humidity']
            lat = response['coord']['lat']
            lng = response['coord']['lon']
            maxtemp = response['main']['temp_max']
            windspeed = response['wind']['speed']

            cityWeather.append({
                'City': city,
                'Cloudiness': cloudiness,
                'Country': country,
                'Humidity': humidity,
                'Lat': lat,
                'Lng': lng,
                'MaxTemp': maxtemp,
                'WindSpeed': windspeed

            })



        time.sleep(1)
# Out:
# Count is 1 city is hoquiam
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=hoquiam
# Count is 2 city is mataura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=mataura
# Count is 3 city is coria
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=coria
# Count is 4 city is taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=taolanaro
# Skipping city taolanaro, city not found
# Count is 5 city is eureka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=eureka
# Count is 6 city is talnakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=talnakh
# Count is 7 city is waitati
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=waitati
# Count is 8 city is tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=tasiilaq
# Count is 9 city is touros
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=touros
# Count is 10 city is peniche
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=peniche
# Count is 11 city is hermanus
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=hermanus
# Count is 12 city is saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=saskylakh
# Count is 13 city is cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=cap malheureux
# Count is 14 city is busselton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=busselton
# Count is 15 city is torbay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=torbay
# Count is 16 city is vaini
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=vaini
# Count is 17 city is jibuti
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=jibuti
# Skipping city jibuti, city not found
# Count is 18 city is eyl
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=eyl
# Count is 19 city is yuancheng
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=yuancheng
# Skipping city yuancheng, city not found
# Count is 20 city is khatanga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=khatanga
# Count is 21 city is yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=yellowknife
# Count is 22 city is hobart
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=hobart
# Count is 23 city is punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=punta arenas
# Count is 24 city is bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=bengkulu
# Skipping city bengkulu, city not found
# Count is 25 city is port alfred
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=port alfred
# Count is 26 city is rikitea
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=rikitea
# Count is 27 city is thompson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=thompson
# Count is 28 city is oga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=oga
# Count is 29 city is lebu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=lebu
# Count is 30 city is puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=puerto ayora
# Count is 31 city is comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=comodoro rivadavia
# Count is 32 city is sabang
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=sabang
# Count is 33 city is tamandare
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=tamandare
# Count is 34 city is albany
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=albany
# Count is 35 city is butaritari
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=butaritari
# Count is 36 city is ancud
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ancud
# Count is 37 city is oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=oranjemund
# Count is 38 city is bluff
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=bluff
# Count is 39 city is sikasso
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=sikasso
# Count is 40 city is madimba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=madimba
# Count is 41 city is kerrville
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kerrville
# Count is 42 city is port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=port elizabeth
# Count is 43 city is plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=plettenberg bay
# Count is 44 city is ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ushuaia
# Count is 45 city is chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=chokurdakh
# Count is 46 city is upernavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=upernavik
# Count is 47 city is iskateley
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=iskateley
# Count is 48 city is emba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=emba
# Count is 49 city is kodiak
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kodiak
# Count is 50 city is qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=qaanaaq
# Count is 51 city is marawi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=marawi
# Count is 52 city is bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=bambous virieux
# Count is 53 city is bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=bredasdorp
# Count is 54 city is vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=vila franca do campo
# Count is 55 city is kota kinabalu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kota kinabalu
# Count is 56 city is saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=saint-philippe
# Count is 57 city is kozhva
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kozhva
# Count is 58 city is east london
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=east london
# Count is 59 city is vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=vaitupu
# Skipping city vaitupu, city not found
# Count is 60 city is kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kaitangata
# Count is 61 city is severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=severo-kurilsk
# Count is 62 city is tucumcari
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=tucumcari
# Count is 63 city is nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=nhulunbuy
# Count is 64 city is mlonggo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=mlonggo
# Count is 65 city is ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ponta do sol
# Count is 66 city is jamestown
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=jamestown
# Count is 67 city is port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=port-gentil
# Count is 68 city is san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=san cristobal
# Count is 69 city is chagda
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=chagda
# Skipping city chagda, city not found
# Count is 70 city is bilokurakyne
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=bilokurakyne
# Count is 71 city is nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=nikolskoye
# Count is 72 city is nome
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=nome
# Count is 73 city is illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=illoqqortoormiut
# Skipping city illoqqortoormiut, city not found
# Count is 74 city is kukushtan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kukushtan
# Count is 75 city is tuy hoa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=tuy hoa
# Count is 76 city is sundsvall
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=sundsvall
# Count is 77 city is fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=fairbanks
# Count is 78 city is cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=cherskiy
# Count is 79 city is barrow
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=barrow
# Count is 80 city is kirakira
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kirakira
# Count is 81 city is qingdao
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=qingdao
# Count is 82 city is hilo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=hilo
# Count is 83 city is jaypur
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=jaypur
# Count is 84 city is mayumba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=mayumba
# Count is 85 city is cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=cabo san lucas
# Count is 86 city is atuona
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=atuona
# Count is 87 city is anuradhapura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=anuradhapura
# Count is 88 city is labuhan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=labuhan
# Count is 89 city is seminole
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=seminole
# Count is 90 city is whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=whitehorse
# Count is 91 city is korcula
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=korcula
# Count is 92 city is voineasa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=voineasa
# Count is 93 city is castro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=castro
# Count is 94 city is katangli
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=katangli
# Count is 95 city is gazli
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=gazli
# Count is 96 city is meyungs
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=meyungs
# Skipping city meyungs, city not found
# Count is 97 city is cape town
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=cape town
# Count is 98 city is baoro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=baoro
# Count is 99 city is codrington
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=codrington
# Count is 100 city is palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=palabuhanratu
# Skipping city palabuhanratu, city not found
# Count is 101 city is vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=vestmanna
# Count is 102 city is kapaa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kapaa
# Count is 103 city is alice springs
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=alice springs
# Count is 104 city is mokhotlong
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=mokhotlong
# Count is 105 city is portland
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=portland
# Count is 106 city is kletskaya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kletskaya
# Count is 107 city is benalla
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=benalla
# Count is 108 city is montmagny
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=montmagny
# Count is 109 city is saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=saint-pierre
# Count is 110 city is victoria
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=victoria
# Count is 111 city is tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=tsihombe
# Skipping city tsihombe, city not found
# Count is 112 city is san juan de los morros
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=san juan de los morros
# Count is 113 city is amderma
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=amderma
# Skipping city amderma, city not found
# Count is 114 city is coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=coahuayana
# Count is 115 city is berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=berdigestyakh
# Count is 116 city is tsabong
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=tsabong
# Count is 117 city is sitka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=sitka
# Count is 118 city is karratha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=karratha
# Count is 119 city is octeville
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=octeville
# Count is 120 city is iracoubo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=iracoubo
# Count is 121 city is kazan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kazan
# Count is 122 city is husavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=husavik
# Count is 123 city is aanekoski
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=aanekoski
# Count is 124 city is souillac
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=souillac
# Count is 125 city is makung
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=makung
# Skipping city makung, city not found
# Count is 126 city is yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=yar-sale
# Count is 127 city is pevek
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=pevek
# Count is 128 city is nguiu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=nguiu
# Skipping city nguiu, city not found
# Count is 129 city is bubaque
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=bubaque
# Count is 130 city is chara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=chara
# Count is 131 city is sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=sentyabrskiy
# Skipping city sentyabrskiy, city not found
# Count is 132 city is toftir
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=toftir
# Skipping city toftir, city not found
# Count is 133 city is chifeng
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=chifeng
# Count is 134 city is boda
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=boda
# Count is 135 city is aklavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=aklavik
# Count is 136 city is ilo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ilo
# Count is 137 city is avarua
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=avarua
# Count is 138 city is pahrump
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=pahrump
# Count is 139 city is higuey
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=higuey
# Skipping city higuey, city not found
# Count is 140 city is atherton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=atherton
# Count is 141 city is nuuk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=nuuk
# Count is 142 city is samusu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=samusu
# Skipping city samusu, city not found
# Count is 143 city is quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=quatre cocos
# Count is 144 city is rossland
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=rossland
# Count is 145 city is simi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=simi
# Count is 146 city is orlik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=orlik
# Count is 147 city is mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=mar del plata
# Count is 148 city is yumen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=yumen
# Count is 149 city is attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=attawapiskat
# Skipping city attawapiskat, city not found
# Count is 150 city is honningsvag
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=honningsvag
# Count is 151 city is barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=barentsburg
# Skipping city barentsburg, city not found
# Count is 152 city is kavieng
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kavieng
# Count is 153 city is durango
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=durango
# Count is 154 city is nyurba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=nyurba
# Count is 155 city is makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=makakilo city
# Count is 156 city is smithers
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=smithers
# Count is 157 city is naryan-mar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=naryan-mar
# Count is 158 city is zarubino
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=zarubino
# Count is 159 city is adamovka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=adamovka
# Count is 160 city is saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=saint-augustin
# Count is 161 city is damietta
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=damietta
# Count is 162 city is kuruman
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kuruman
# Count is 163 city is sigli
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=sigli
# Count is 164 city is evensk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=evensk
# Count is 165 city is banmo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=banmo
# Skipping city banmo, city not found
# Count is 166 city is necochea
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=necochea
# Count is 167 city is saint george
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=saint george
# Count is 168 city is lolua
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=lolua
# Skipping city lolua, city not found
# Count is 169 city is vanimo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=vanimo
# Count is 170 city is sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=sobolevo
# Count is 171 city is maningrida
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=maningrida
# Count is 172 city is cidreira
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=cidreira
# Count is 173 city is fortuna
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=fortuna
# Count is 174 city is kerman
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kerman
# Count is 175 city is faanui
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=faanui
# Count is 176 city is redcar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=redcar
# Count is 177 city is san quintin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=san quintin
# Count is 178 city is nichinan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=nichinan
# Count is 179 city is sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=sao joao da barra
# Count is 180 city is omboue
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=omboue
# Count is 181 city is new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=new norfolk
# Count is 182 city is rungata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=rungata
# Skipping city rungata, city not found
# Count is 183 city is dikson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=dikson
# Count is 184 city is fukue
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=fukue
# Count is 185 city is falealupo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=falealupo
# Skipping city falealupo, city not found
# Count is 186 city is deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=deputatskiy
# Count is 187 city is grindavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=grindavik
# Count is 188 city is tromso
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=tromso
# Count is 189 city is tucuman
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=tucuman
# Count is 190 city is sozimskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=sozimskiy
# Count is 191 city is kabarnet
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kabarnet
# Count is 192 city is pangody
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=pangody
# Count is 193 city is san ignacio
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=san ignacio
# Count is 194 city is ambon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ambon
# Count is 195 city is gazalkent
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=gazalkent
# Count is 196 city is marzuq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=marzuq
# Count is 197 city is cloquet
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=cloquet
# Count is 198 city is bara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=bara
# Count is 199 city is podujevo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=podujevo
# Skipping city podujevo, city not found
# Count is 200 city is urumqi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=urumqi
# Skipping city urumqi, city not found
# Count is 201 city is isla vista
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=isla vista
# Count is 202 city is luderitz
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=luderitz
# Count is 203 city is tonekabon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=tonekabon
# Count is 204 city is airai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=airai
# Count is 205 city is vila velha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=vila velha
# Count is 206 city is college
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=college
# Count is 207 city is malaya vishera
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=malaya vishera
# Count is 208 city is banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=banda aceh
# Count is 209 city is batemans bay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=batemans bay
# Count is 210 city is mmabatho
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=mmabatho
# Count is 211 city is nelson bay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=nelson bay
# Count is 212 city is blairmore
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=blairmore
# Count is 213 city is limon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=limon
# Count is 214 city is istok
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=istok
# Count is 215 city is ahipara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ahipara
# Count is 216 city is umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=umzimvubu
# Skipping city umzimvubu, city not found
# Count is 217 city is sandnessjoen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=sandnessjoen
# Count is 218 city is georgetown
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=georgetown
# Count is 219 city is tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=tuatapere
# Count is 220 city is bac lieu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=bac lieu
# Skipping city bac lieu, city not found
# Count is 221 city is shimoda
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=shimoda
# Count is 222 city is grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=grand river south east
# Skipping city grand river south east, city not found
# Count is 223 city is kamwenge
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kamwenge
# Count is 224 city is panguna
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=panguna
# Count is 225 city is igunga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=igunga
# Count is 226 city is mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=mys shmidta
# Skipping city mys shmidta, city not found
# Count is 227 city is rabo de peixe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=rabo de peixe
# Count is 228 city is sept-iles
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=sept-iles
# Count is 229 city is yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=yerbogachen
# Count is 230 city is vardo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=vardo
# Count is 231 city is bethel
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=bethel
# Count is 232 city is santa fe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=santa fe
# Count is 233 city is cairns
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=cairns
# Count is 234 city is sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=sao filipe
# Count is 235 city is waipawa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=waipawa
# Count is 236 city is paragominas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=paragominas
# Count is 237 city is parabel
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=parabel
# Count is 238 city is manggar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=manggar
# Count is 239 city is srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=srednekolymsk
# Count is 240 city is lesnoy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=lesnoy
# Count is 241 city is altay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=altay
# Count is 242 city is lhokseumawe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=lhokseumawe
# Count is 243 city is petatlan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=petatlan
# Count is 244 city is nemuro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=nemuro
# Count is 245 city is ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ixtapa
# Count is 246 city is belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=belushya guba
# Skipping city belushya guba, city not found
# Count is 247 city is guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=guerrero negro
# Count is 248 city is tungkang
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=tungkang
# Skipping city tungkang, city not found
# Count is 249 city is grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=grand gaube
# Count is 250 city is cheuskiny
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=cheuskiny
# Skipping city cheuskiny, city not found
# Count is 251 city is tautira
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=tautira
# Count is 252 city is kuantan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kuantan
# Count is 253 city is baghmara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=baghmara
# Count is 254 city is grebanu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=grebanu
# Skipping city grebanu, city not found
# Count is 255 city is pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=pangnirtung
# Count is 256 city is chuy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=chuy
# Count is 257 city is el dorado
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=el dorado
# Count is 258 city is asfi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=asfi
# Skipping city asfi, city not found
# Count is 259 city is monte alegre
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=monte alegre
# Count is 260 city is iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=iqaluit
# Count is 261 city is nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=nouadhibou
# Count is 262 city is berlevag
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=berlevag
# Count is 263 city is pasighat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=pasighat
# Count is 264 city is dunedin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=dunedin
# Count is 265 city is mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=mount gambier
# Count is 266 city is beatrice
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=beatrice
# Count is 267 city is rawannawi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=rawannawi
# Skipping city rawannawi, city not found
# Count is 268 city is saldanha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=saldanha
# Count is 269 city is namibe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=namibe
# Count is 270 city is marcona
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=marcona
# Skipping city marcona, city not found
# Count is 271 city is maceio
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=maceio
# Count is 272 city is tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=tuktoyaktuk
# Count is 273 city is hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=hithadhoo
# Count is 274 city is sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=sisimiut
# Count is 275 city is thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=thinadhoo
# Count is 276 city is osmanabad
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=osmanabad
# Count is 277 city is kabelvag
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kabelvag
# Count is 278 city is gantt
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=gantt
# Count is 279 city is ca mau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ca mau
# Count is 280 city is klyuchi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=klyuchi
# Count is 281 city is abha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=abha
# Count is 282 city is geraldton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=geraldton
# Count is 283 city is san patricio
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=san patricio
# Count is 284 city is ratnagiri
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ratnagiri
# Count is 285 city is mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=mahebourg
# Count is 286 city is qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=qaqortoq
# Count is 287 city is bandhi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=bandhi
# Count is 288 city is narsaq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=narsaq
# Count is 289 city is kolpashevo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kolpashevo
# Count is 290 city is cravo norte
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=cravo norte
# Count is 291 city is buala
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=buala
# Count is 292 city is klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=klaksvik
# Count is 293 city is tiksi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=tiksi
# Count is 294 city is pecos
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=pecos
# Count is 295 city is grand forks
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=grand forks
# Count is 296 city is raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=raudeberg
# Count is 297 city is alihe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=alihe
# Count is 298 city is kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kudahuvadhoo
# Count is 299 city is hasaki
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=hasaki
# Count is 300 city is asau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=asau
# Skipping city asau, city not found
# Count is 301 city is gaziantep
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=gaziantep
# Count is 302 city is rondonopolis
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=rondonopolis
# Count is 303 city is noumea
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=noumea
# Count is 304 city is roebourne
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=roebourne
# Count is 305 city is itarema
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=itarema
# Count is 306 city is aykhal
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=aykhal
# Count is 307 city is west lafayette
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=west lafayette
# Count is 308 city is longlac
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=longlac
# Skipping city longlac, city not found
# Count is 309 city is ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ribeira grande
# Count is 310 city is komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=komsomolskiy
# Count is 311 city is marsa matruh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=marsa matruh
# Count is 312 city is los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=los llanos de aridane
# Count is 313 city is nabire
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=nabire
# Count is 314 city is changli
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=changli
# Count is 315 city is durres
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=durres
# Count is 316 city is rio branco
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=rio branco
# Count is 317 city is kasempa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kasempa
# Count is 318 city is rong kwang
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=rong kwang
# Count is 319 city is okakarara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=okakarara
# Count is 320 city is isangel
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=isangel
# Count is 321 city is aasiaat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=aasiaat
# Count is 322 city is rafraf
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=rafraf
# Count is 323 city is olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=olafsvik
# Skipping city olafsvik, city not found
# Count is 324 city is puerto santander
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=puerto santander
# Count is 325 city is khonuu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=khonuu
# Skipping city khonuu, city not found
# Count is 326 city is paz de ariporo
# ...
# Skipping city catamarca, city not found
# Count is 512 city is ercis
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ercis
# Count is 513 city is poso
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=poso
# Count is 514 city is toungoo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=toungoo
# Skipping city toungoo, city not found
# Count is 515 city is aketi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=aketi
# Count is 516 city is lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=lavrentiya
# Count is 517 city is puerto leguizamo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=puerto leguizamo
# Count is 518 city is ribeira brava
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ribeira brava
# Count is 519 city is uralskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=uralskiy
# Skipping city uralskiy, city not found
# Count is 520 city is pangai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=pangai
# Count is 521 city is dibulla
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=dibulla
# Count is 522 city is margate
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=margate
# Count is 523 city is gorokhovets
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=gorokhovets
# Count is 524 city is kemise
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kemise
# Count is 525 city is tual
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=tual
# Count is 526 city is magomeni
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=magomeni
# Count is 527 city is tuam
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=tuam
# Count is 528 city is sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=sao jose da coroa grande
# Count is 529 city is jizan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=jizan
# Count is 530 city is whitefish
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=whitefish
# Count is 531 city is shahr-e kord
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=shahr-e kord
# Count is 532 city is henties bay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=henties bay
# Count is 533 city is carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=carnarvon
# Count is 534 city is sokolovo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=sokolovo
# Count is 535 city is sambava
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=sambava
# Count is 536 city is rocha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=rocha
# Count is 537 city is kahului
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kahului
# Count is 538 city is bukachacha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=bukachacha
# Count is 539 city is ust-kamchatsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ust-kamchatsk
# Skipping city ust-kamchatsk, city not found
# Count is 540 city is belyy yar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=belyy yar
# Count is 541 city is la asuncion
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=la asuncion
# Count is 542 city is oriximina
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=oriximina
# Count is 543 city is richards bay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=richards bay
# Count is 544 city is alotau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=alotau
# Skipping city alotau, city not found
# Count is 545 city is kichera
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kichera
# Count is 546 city is lingao
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=lingao
# Count is 547 city is miles city
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=miles city
# Count is 548 city is adrar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=adrar
# Count is 549 city is mullaitivu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=mullaitivu
# Skipping city mullaitivu, city not found
# Count is 550 city is faya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=faya
# Count is 551 city is onguday
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=onguday
# Count is 552 city is praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=praia da vitoria
# Count is 553 city is imbituba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=imbituba
# Count is 554 city is mbeya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=mbeya
# Count is 555 city is ewa beach
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ewa beach
# Count is 556 city is tezu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=tezu
# Count is 557 city is hegang
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=hegang
# Count is 558 city is ahtopol
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ahtopol
# Count is 559 city is kidal
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kidal
# Count is 560 city is yulara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=yulara
# Count is 561 city is bahia blanca
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=bahia blanca
# Count is 562 city is ararangua
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ararangua
# Count is 563 city is motomiya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=motomiya
# Count is 564 city is jipijapa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=jipijapa
# Count is 565 city is campos
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=campos
# Count is 566 city is ronne
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ronne
# Count is 567 city is baracoa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=baracoa
# Count is 568 city is rodez
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=rodez
# Count is 569 city is paamiut
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=paamiut
# Count is 570 city is kapoeta
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kapoeta
# Skipping city kapoeta, city not found
# Count is 571 city is marienburg
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=marienburg
# Count is 572 city is biloela
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=biloela
# Count is 573 city is bonthe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=bonthe
# Count is 574 city is xuddur
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=xuddur
# Count is 575 city is chuguyevka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=chuguyevka
# Count is 576 city is bom jesus
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=bom jesus
# Count is 577 city is abiy adi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=abiy adi
# Skipping city abiy adi, city not found
# Count is 578 city is benguela
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=benguela
# Count is 579 city is sayyan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=sayyan
# Count is 580 city is joigny
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=joigny
# Count is 581 city is veraval
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=veraval
# Count is 582 city is merauke
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=merauke
# Count is 583 city is yunjinghong
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=yunjinghong
# Skipping city yunjinghong, city not found
# Count is 584 city is maues
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=maues
# Count is 585 city is fenoarivo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=fenoarivo
# Count is 586 city is maumere
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=maumere
# Count is 587 city is coldwater
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=coldwater
# Count is 588 city is trairi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=trairi
# Count is 589 city is seddon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=seddon
# Count is 590 city is khorramshahr
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=khorramshahr
# Count is 591 city is pasinler
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=pasinler
# Count is 592 city is maragogi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=maragogi
# Count is 593 city is kitimat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kitimat
# Count is 594 city is jojoima
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=jojoima
# Count is 595 city is iseyin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=iseyin
# Count is 596 city is betsiamites
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=betsiamites
# Count is 597 city is san andres
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=san andres
# Count is 598 city is zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=zhigansk
# Count is 599 city is jining
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=jining
# Count is 600 city is ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ulladulla
# Count is 601 city is teguldet
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=teguldet
# Count is 602 city is khryashchevka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=khryashchevka
# Count is 603 city is ocozocoautla
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=ocozocoautla
# Skipping city ocozocoautla, city not found
# Count is 604 city is beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=beringovskiy
# Count is 605 city is novyy urengoy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=novyy urengoy
# Count is 606 city is goteborg
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=goteborg
# Skipping city goteborg, city not found
# Count is 607 city is hongjiang
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=hongjiang
# Count is 608 city is goderich
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=goderich
# Count is 609 city is skjervoy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=skjervoy
# Count is 610 city is sandeid
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=sandeid
# Count is 611 city is nola
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=nola
# Count is 612 city is namatanai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=namatanai
# Count is 613 city is morro bay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=morro bay
# Count is 614 city is aden
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=aden
# Count is 615 city is belmonte
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=belmonte
# Count is 616 city is moose factory
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=moose factory
# Count is 617 city is hauterive
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=hauterive
# Count is 618 city is hanzhong
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=hanzhong
# Count is 619 city is kenora
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=kenora
# Count is 620 city is gushikawa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=f6037b60b7920e9d74f375258d824e09&q=gushikawa

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
if USEAPI:
    cityWeatherDF = pd.DataFrame(cityWeather)
    cityWeatherDF.to_csv(output_data_file, index=False, encoding='utf-8')

# %%
if USEAPI == False: # we are not calling weather api, 
    # Read in csv and load dataframe
    cityWeatherDF = pd.read_csv(output_data_file)
    cityWeatherDF

# %%
cityWeatherDF.head(10)
# Out:
#        City  Cloudiness Country  Humidity    Lat     Lng  MaxTemp  WindSpeed
# 0   hoquiam          75      US        77  46.98 -123.89    66.00       9.17
# 1   mataura          96      NZ        94 -46.19  168.86    39.00       1.01
# 2     coria          39      ES        21  39.98   -6.54    93.99       3.00
# 3    eureka          90      US        93  40.80 -124.16    64.99      23.33
# 4   talnakh          10      RU        87  69.49   88.39    57.20       4.47
# 5   waitati          75      NZ        80 -45.75  170.57    43.00       1.99
# 6  tasiilaq          75      GL        70  65.61  -37.64    44.60      14.99
# 7    touros          40      BR        62  -5.20  -35.46    84.20      13.87
# 8   peniche           0      PT        39  39.36   -9.38    86.00       9.17
# 9  hermanus          50      ZA        96 -34.42   19.24    57.99       1.01

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# X will be lat, Y will be Temp
x_axis = cityWeatherDF['Lat']
y_axis = cityWeatherDF['MaxTemp']




# Scatter plot
plt.scatter(x_axis, y_axis, marker="o", facecolors="green", edgecolors="yellow", alpha=0.75)

sDate = pd.Timestamp("today").strftime("%m/%d/%Y")

# Titles/Labels
plt.title(f'Latitude vs. Temperature Plot ({sDate})')
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.show()
plt.savefig('output/LatVsTemp.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# X will be lat, Y will be Humidity
x_axis = cityWeatherDF['Lat']
y_axis = cityWeatherDF['Humidity']




# Scatter plot
plt.scatter(x_axis, y_axis, marker="o", facecolors="green", edgecolors="yellow", alpha=0.75)

sDate = pd.Timestamp("today").strftime("%m/%d/%Y")

# Titles/Labels
plt.title(f'Latitude vs. Humidity Plot ({sDate})')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.show()
plt.savefig('output/LatVsHumidity.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# X will be lat, Y will be Humidity
x_axis = cityWeatherDF['Lat']
y_axis = cityWeatherDF['Cloudiness']




# Scatter plot
plt.scatter(x_axis, y_axis, marker="o", facecolors="green", edgecolors="yellow", alpha=0.75)

sDate = pd.Timestamp("today").strftime("%m/%d/%Y")

# Titles/Labels
plt.title(f'Latitude vs. Cloudiness Plot ({sDate})')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.show()
plt.savefig('output/LatVsClouds.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# X will be lat, Y will be Humidity
x_axis = cityWeatherDF['Lat']
y_axis = cityWeatherDF['WindSpeed']




# Scatter plot
plt.scatter(x_axis, y_axis, marker="o", facecolors="green", edgecolors="yellow", alpha=0.75)

sDate = pd.Timestamp("today").strftime("%m/%d/%Y")

# Titles/Labels
plt.title(f'Latitude vs. Wind Speed Plot ({sDate})')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.show()
plt.savefig('output/LatVsWindSpd.png')
